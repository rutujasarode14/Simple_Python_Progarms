# %% [markdown]
# <a href="https://colab.research.google.com/github/rutujasarode14/Simple_Python_Progarms/blob/main/E1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def factorial(n):
    if n < 0:
        return "Factorial is not defined for negative numbers"
    elif n == 0:
        return 1
    else:
        result = 1
        for i in range(1, n + 1):
            result *= i
        return result

# Example usage:
num = 5
print(f"The factorial of {num} is {factorial(num)}")
# Out:
# The factorial of 5 is 120

# %%
# Identify if a number is even or odd
num = 10  # You can change this to any number

if num % 2 == 0:
    print(f"{num} is an Even number.")
else:
    print(f"{num} is an Odd number.")

# %%
# Multiplication table for a given number
num = 7  # You can change this to any number

print(f"Multiplication Table for {num}:")
for i in range(1, 11):
    print(f"{num} x {i} = {num * i}")
# Out:
# Multiplication Table for 7:
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# 7 x 7 = 49
# 7 x 8 = 56
# 7 x 9 = 63
# 7 x 10 = 70

# %%
# Identify if a number is even or odd
num = 10  # Change this value to test other numbers

if num % 2 == 0:
    print(f"{num} is an Even number.")
else:
    print(f"{num} is an Odd number.")
# Out:
# 10 is an Even number.

# %%
def check_palindrome(n):
    temp = n
    reverse_num = 0
    while n > 0:
        digit = n % 10
        reverse_num = reverse_num * 10 + digit
        n = n // 10

    if temp == reverse_num:
        return True
    else:
        return False

# Example usage:
num = 121
if check_palindrome(num):
    print(f"{num} is a palindrome.")
else:
    print(f"{num} is not a palindrome.")
# Out:
# 121 is a palindrome.

# %%
# Simple Expert System for Disease Diagnosis
def expert_system():
    print("=== Medical Diagnosis Expert System ===")
    fever = input("Do you have fever? (yes/no): ").lower()
    cough = input("Do you have cough? (yes/no): ").lower()
    headache = input("Do you have headache? (yes/no): ").lower()
    sneezing = input("Do you have sneezing? (yes/no): ").lower()

    # Inference Engine (Rules)
    if fever == "yes" and cough == "yes" and headache == "yes":
        diagnosis = "You may have FLU."
    elif sneezing == "yes" and cough == "yes" and fever == "no":
        diagnosis = "You may have COMMON COLD."
    elif fever == "yes" and headache == "yes":
        diagnosis = "You may have VIRAL FEVER."
    else:
        diagnosis = "Condition unclear. Please consult a doctor."

    print("\nDiagnosis Result:")
    print(diagnosis)

# Run the expert system
expert_system()
# Out:
# === Medical Diagnosis Expert System ===
# Do you have fever? (yes/no): yes
# Do you have cough? (yes/no): yes
# Do you have headache? (yes/no): yes
# Do you have sneezing? (yes/no): yes
#
# Diagnosis Result:
# You may have FLU.
