# %% [markdown]
# <a href="https://colab.research.google.com/github/rutujasarode14/Simple_Python_Progarms/blob/main/A_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Generate 1000 random numbers from normal distribution
mean = 0
std_dev = 1

data = np.random.normal(mean, std_dev, 1000)

# Plot histogram
plt.hist(data, bins=30, edgecolor='black', density=True, alpha=0.6, color='skyblue')

# Plot theoretical normal curve
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = stats.norm.pdf(x, mean, std_dev)

plt.plot(x, p, 'r', linewidth=2)
plt.title("Normal Distribution")
plt.xlabel("Values")
plt.ylabel("Density")
plt.show()

# %%
print("Mean:", np.mean(data))
print("Median:", np.median(data))
print("Variance:", np.var(data))
print("Standard Deviation:", np.std(data))
# Out:
# Mean: 0.01423803428011226
# Median: -0.01483225886540164
# Variance: 0.9508187667965992
# Standard Deviation: 0.9750993625249681

# %%
# Simulate 1000 coin tosses
tosses = np.random.choice(['H', 'T'], size=1000)

heads = np.sum(tosses == 'H')
tails = np.sum(tosses == 'T')

print("Number of Heads:", heads)
print("Number of Tails:", tails)
print("Probability of Heads:", heads/1000)
print("Probability of Tails:", tails/1000)
# Out:
# Number of Heads: 516
# Number of Tails: 484
# Probability of Heads: 0.516
# Probability of Tails: 0.484

# %%
plt.bar(['Heads', 'Tails'], [heads, tails], color=['green', 'red'])
plt.title("Coin Toss Simulation")
plt.ylabel("Count")
plt.show()
